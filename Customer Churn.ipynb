# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("telecom_customer_churn.csv")

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                     0  Frazier Park
# 1  0003-MKNFE    Male   46      No                     0      Glendale
# 2  0004-TLHLJ    Male   50      No                     0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                     0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                     0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073                    2  ...      Credit Card
# 1     91206  34.162515 -118.203869                    0  ...      Credit Card
# 2     92627  33.645672 -117.922613                    0  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432                    1  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903                    3  ...      Credit Card
#
# ...

# %%
df.shape
# Out:
# (7043, 38)

# %%
df.tail()
# Out:
#      Customer ID  Gender  Age Married  Number of Dependents          City  \
# 7038  9987-LUTYD  Female   20      No                     0       La Mesa
# 7039  9992-RRAMN    Male   40     Yes                     0     Riverbank
# 7040  9992-UJOEL    Male   22      No                     0           Elk
# 7041  9993-LHIEB    Male   21     Yes                     0  Solana Beach
# 7042  9995-HOTOH    Male   36     Yes                     0   Sierra City
#
#       Zip Code   Latitude   Longitude  Number of Referrals  ...  \
# 7038     91941  32.759327 -116.997260                    0  ...
# 7039     95367  37.734971 -120.954271                    1  ...
# 7040     95432  39.108252 -123.645121                    0  ...
# 7041     92075  33.001813 -117.263628                    5  ...
# 7042     96125  39.600599 -120.636358                    1  ...
#
#        Payment Method Monthly Charge Total Charges  Total Refunds  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7043 entries, 0 to 7042
# Data columns (total 38 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   Customer ID                        7043 non-null   object
#  1   Gender                             7043 non-null   object
#  2   Age                                7043 non-null   int64
#  3   Married                            7043 non-null   object
#  4   Number of Dependents               7043 non-null   int64
#  5   City                               7043 non-null   object
#  6   Zip Code                           7043 non-null   int64
#  7   Latitude                           7043 non-null   float64
#  8   Longitude                          7043 non-null   float64
#  9   Number of Referrals                7043 non-null   int64
#  10  Tenure in Months                   7043 non-null   int64
# ...

# %%
df.describe()
# Out:
#                Age  Number of Dependents      Zip Code     Latitude  \
# count  7043.000000           7043.000000   7043.000000  7043.000000
# mean     46.509726              0.468692  93486.070567    36.197455
# std      16.750352              0.962802   1856.767505     2.468929
# min      19.000000              0.000000  90001.000000    32.555828
# 25%      32.000000              0.000000  92101.000000    33.990646
# 50%      46.000000              0.000000  93518.000000    36.205465
# 75%      60.000000              0.000000  95329.000000    38.161321
# max      80.000000              9.000000  96150.000000    41.962127
#
#          Longitude  Number of Referrals  Tenure in Months  \
# count  7043.000000          7043.000000       7043.000000
# mean   -119.756684             1.951867         32.386767
# std       2.154425             3.001199         24.542061
# min    -124.301372             0.000000          1.000000
# 25%    -121.788090             0.000000          9.000000
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status', 'Churn Category', 'Churn Reason'],
#       dtype='object')

# %%
df.dtypes
# Out:
# Customer ID                           object
# Gender                                object
# Age                                    int64
# Married                               object
# Number of Dependents                   int64
# City                                  object
# Zip Code                               int64
# Latitude                             float64
# Longitude                            float64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Phone Service                         object
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                        object
# Internet Service                      object
# Internet Type                         object
# Avg Monthly GB Download              float64
# Online Security                       object
# Online Backup                         object
# Device Protection Plan                object
# ...

# %%
missing_counts = df.isnull().sum()
print(missing_counts)
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                   0
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %%
missing_percentage = (missing_counts/len(df))*100
print(missing_percentage)
# Out:
# Customer ID                           0.000000
# Gender                                0.000000
# Age                                   0.000000
# Married                               0.000000
# Number of Dependents                  0.000000
# City                                  0.000000
# Zip Code                              0.000000
# Latitude                              0.000000
# Longitude                             0.000000
# Number of Referrals                   0.000000
# Tenure in Months                      0.000000
# Offer                                 0.000000
# Phone Service                         0.000000
# Avg Monthly Long Distance Charges     9.683374
# Multiple Lines                        9.683374
# Internet Service                      0.000000
# Internet Type                        21.666903
# Avg Monthly GB Download              21.666903
# Online Security                      21.666903
# Online Backup                        21.666903
# ...

# %%
def null_value_plot(missing_counts):
    missing_counts = missing_counts[missing_counts>0]
    missing_counts.plot(kind='bar',figsize=(10,6))
    plt.title('Missing Values Count By Column')
    plt.xlabel("Columns")
    plt.ylabel("Missing Value Count")
    plt.xticks(rotation=90)
    plt.show()
null_value_plot(missing_counts)

# %%
def null_percentage_plot(missing_percentage):
    missing_percentage = missing_percentage[missing_percentage>0]
    missing_percentage.plot(kind='bar', figsize=(10,6))
    plt.title('Missing Values Percentage By Column')
    plt.xlabel("Columns")
    plt.ylabel("Missing Value percentage")
    plt.xticks(rotation=90)
    plt.show()
null_percentage_plot(missing_percentage)

# %%
duplicate_count = df.duplicated()
print(duplicate_count)
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 7038    False
# 7039    False
# 7040    False
# 7041    False
# 7042    False
# Length: 7043, dtype: bool

# %%
plt.figure(figsize=(10,6))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis', yticklabels=False)
plt.title("Heatmap of Missing Values")
plt.show()

# %%
df.drop(columns=['Churn Category'],inplace=True)
df.drop(columns=['Churn Reason'],inplace=True)

# %%
df.dtypes
# Out:
# Customer ID                           object
# Gender                                object
# Age                                    int64
# Married                               object
# Number of Dependents                   int64
# City                                  object
# Zip Code                               int64
# Latitude                             float64
# Longitude                            float64
# Number of Referrals                    int64
# Tenure in Months                       int64
# Offer                                 object
# Phone Service                         object
# Avg Monthly Long Distance Charges    float64
# Multiple Lines                        object
# Internet Service                      object
# Internet Type                         object
# Avg Monthly GB Download              float64
# Online Security                       object
# Online Backup                         object
# Device Protection Plan                object
# ...

# %%
missing_counts = df.isnull().sum()
print(missing_counts)
# Out:
# Customer ID                             0
# Gender                                  0
# Age                                     0
# Married                                 0
# Number of Dependents                    0
# City                                    0
# Zip Code                                0
# Latitude                                0
# Longitude                               0
# Number of Referrals                     0
# Tenure in Months                        0
# Offer                                   0
# Phone Service                           0
# Avg Monthly Long Distance Charges     682
# Multiple Lines                        682
# Internet Service                        0
# Internet Type                        1526
# Avg Monthly GB Download              1526
# Online Security                      1526
# Online Backup                        1526
# Device Protection Plan               1526
# Premium Tech Support                 1526
# ...

# %%
null_value_plot(missing_counts)

# %%
numerical_columns = df.select_dtypes(include=['int64','float64']).columns
print(numerical_columns)
# Out:
# Index(['Age', 'Number of Dependents', 'Zip Code', 'Latitude', 'Longitude',
#        'Number of Referrals', 'Tenure in Months',
#        'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download',
#        'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue'],
#       dtype='object')

# %%
categorical_colums = df.select_dtypes(include=['object','category']).columns
print(categorical_colums)
# Out:
# Index(['Customer ID', 'Gender', 'Married', 'City', 'Offer', 'Phone Service',
#        'Multiple Lines', 'Internet Service', 'Internet Type',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Customer Status'],
#       dtype='object')

# %%
df['Avg Monthly Long Distance Charges'].fillna(df['Avg Monthly Long Distance Charges'].mean(), inplace=True)
df['Avg Monthly GB Download'].fillna(df['Avg Monthly GB Download'].mean(), inplace=True)

# %%
categoriacl_column_tofill = ['Multiple Lines','Internet Type','Online Security', 'Online Backup', 'Device Protection Plan',
       'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
       'Streaming Music', 'Unlimited Data']

for col in categoriacl_column_tofill:
    mode_value = df[col].mode()[0]
    df[col].fillna(mode_value, inplace=True)

# %%
missing_counts = df.isnull().sum()
print(missing_counts)
# Out:
# Customer ID                          0
# Gender                               0
# Age                                  0
# Married                              0
# Number of Dependents                 0
# City                                 0
# Zip Code                             0
# Latitude                             0
# Longitude                            0
# Number of Referrals                  0
# Tenure in Months                     0
# Offer                                0
# Phone Service                        0
# Avg Monthly Long Distance Charges    0
# Multiple Lines                       0
# Internet Service                     0
# Internet Type                        0
# Avg Monthly GB Download              0
# Online Security                      0
# Online Backup                        0
# Device Protection Plan               0
# Premium Tech Support                 0
# Streaming TV                         0
# Streaming Movies                     0
# ...

# %%
#checking Class Balance
class_percentage = df['Customer Status'].value_counts(normalize = True)*100
print(class_percentage)
# Out:
# Stayed     67.016896
# Churned    26.536987
# Joined      6.446117
# Name: Customer Status, dtype: float64

# %%
#EDA

# %%
import matplotlib.pyplot as plt

df['Customer Status'].value_counts().plot(kind='bar', color=['blue', 'orange', 'green'])
plt.title('Distribution of Customer Status')
plt.xlabel('Customer Status')
plt.ylabel('Count')
plt.xticks(rotation=0)
plt.show()

# %%
numerical_columns = ['Age', 'Number of Dependents', 'Zip Code', 'Latitude', 'Longitude',
                     'Number of Referrals', 'Tenure in Months',
                     'Avg Monthly Long Distance Charges', 'Avg Monthly GB Download',
                     'Monthly Charge', 'Total Charges', 'Total Refunds',
                     'Total Extra Data Charges', 'Total Long Distance Charges',
                     'Total Revenue']

# Create subplots: 4 rows, 4 columns (adjust rows/cols depending on the number of features)
fig, axes = plt.subplots(nrows=4, ncols=4, figsize=(20, 15))

# Flatten the axes array to easily iterate through it
axes = axes.flatten()

# Loop through each numerical column and create a histogram in a subplot
for i, col in enumerate(numerical_columns):
    df[col].plot(kind='hist', ax=axes[i], bins=30, color='skyblue', edgecolor='black')
    axes[i].set_title(col)
    axes[i].set_xlabel('Value')
    axes[i].set_ylabel('Frequency')

# # Hide any unused subplots (in case the number of columns doesn't fit perfectly in the grid)
for j in range(i + 1, len(axes)):
    axes[j].set_visible(False)

# Adjust the layout to prevent overlap
plt.tight_layout()

# Show the figure
plt.show()

# %%
skewness = df[numerical_columns].skew()
skewness
# Out:
# Age                                  0.162186
# Number of Dependents                 2.109932
# Zip Code                            -0.209615
# Latitude                             0.314804
# Longitude                           -0.091932
# Number of Referrals                  1.446060
# Tenure in Months                     0.240543
# Avg Monthly Long Distance Charges   -0.002074
# Avg Monthly GB Download              1.337747
# Monthly Charge                      -0.275394
# Total Charges                        0.963791
# Total Refunds                        4.328517
# Total Extra Data Charges             4.091209
# Total Long Distance Charges          1.238282
# Total Revenue                        0.919410
# dtype: float64

# %%
#Moderately Skewed Features
features_to_apply_sqrt_tranformation = ['Number of Referrals','Avg Monthly GB Download','Total Charges',
'Total Long Distance Charges','Total Revenue']
# df['feature_name'] = np.sqrt(df['feature_name'])

for features in features_to_apply_sqrt_tranformation:
    df[features] = np.sqrt(df[features].clip(lower=0))

# %%
# Logarithmic Transformation:
features_to_apply_log_tranformation = ['Number of Dependents','Total Refunds','Total Extra Data Charges']

for features in features_to_apply_log_tranformation:
    df[features] = np.log1p(df[features].clip(lower=0))

# %%
skewness = df[numerical_columns].skew()
skewness
# Out:
# Age                                  0.162186
# Number of Dependents                 1.591533
# Zip Code                            -0.209615
# Latitude                             0.314804
# Longitude                           -0.091932
# Number of Referrals                  0.820685
# Tenure in Months                     0.240543
# Avg Monthly Long Distance Charges   -0.002074
# Avg Monthly GB Download              0.386848
# Monthly Charge                      -0.275394
# Total Charges                        0.311431
# Total Refunds                        3.486093
# Total Extra Data Charges             2.854589
# Total Long Distance Charges          0.384727
# Total Revenue                        0.226727
# dtype: float64

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status'],
#       dtype='object')

# %%
from sklearn.preprocessing import LabelEncoder
label_encoder = LabelEncoder()
df['Customer Status Encoded'] = label_encoder.fit_transform(df['Customer Status'])

# %%
print(df['Customer Status Encoded'])
# Out:
# 0       2
# 1       2
# 2       0
# 3       0
# 4       0
#        ..
# 7038    2
# 7039    0
# 7040    1
# 7041    2
# 7042    2
# Name: Customer Status Encoded, Length: 7043, dtype: int64

# %%
correlations = {}

# Calculate correlations for all numerical columns
for col in numerical_columns:
    correlations[col] = df[col].corr(df['Customer Status Encoded'])
    print(f'Correlation between {col} and Customer Status: {correlations[col]}')  # Fixed variable reference
    print("")

# Convert the dictionary to a Pandas Series
correlations_series = pd.Series(correlations)

# Plot the correlations
correlations_series.plot(kind='bar', figsize=(10, 6), color='skyblue', edgecolor='black')
plt.title('Correlations with Customer Status')
plt.xlabel('Features')
plt.ylabel('Correlation')
plt.show()
# Out:
# Correlation between Age and Customer Status: -0.10042109180291654
#
# Correlation between Number of Dependents and Customer Status: 0.24634326691966557
#
# Correlation between Zip Code and Customer Status: 0.019491092819894792
#
# Correlation between Latitude and Customer Status: 0.0427590632480183
#
# Correlation between Longitude and Customer Status: -0.024665296156119933
#
# Correlation between Number of Referrals and Customer Status: 0.2983645366347231
#
# Correlation between Tenure in Months and Customer Status: 0.4464114395296162
#
# Correlation between Avg Monthly Long Distance Charges and Customer Status: 0.0027369472907729747
#
# Correlation between Avg Monthly GB Download and Customer Status: 0.10408600221232549
#
# Correlation between Monthly Charge and Customer Status: -0.13985449909816372
#
# Correlation between Total Charges and Customer Status: 0.3233004291975401
#
# Correlation between Total Refunds and Customer Status: 0.05551652093253486
#
# ...

# %%
categorical_columns= ['Multiple Lines', 'Internet Type', 'Online Security', 'Online Backup',
                               'Device Protection Plan', 'Premium Tech Support', 'Streaming TV',
                               'Streaming Movies', 'Streaming Music', 'Unlimited Data']

# Loop through each column and plot countplot
for col in categorical_columns:
    sns.countplot(x=col, data=df)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
categorical_columns= ['Multiple Lines', 'Internet Type', 'Online Security', 'Online Backup',
                               'Device Protection Plan', 'Premium Tech Support', 'Streaming TV',
                               'Streaming Movies', 'Streaming Music', 'Unlimited Data']

# Loop through each column and plot countplot
for col in categorical_columns:
    sns.countplot(x=col, hue='Customer Status', data=df)
    plt.title(f'Distribution of {col}')
    plt.xlabel(col)
    plt.ylabel('Count')
    plt.show()

# %%
for col in categorical_columns:
    print(f'Distribution of {col}:')
    print(df[col].value_counts())
    print()
# Out:
# Distribution of Multiple Lines:
# No     4072
# Yes    2971
# Name: Multiple Lines, dtype: int64
#
# Distribution of Internet Type:
# Fiber Optic    4561
# DSL            1652
# Cable           830
# Name: Internet Type, dtype: int64
#
# Distribution of Online Security:
# No     5024
# Yes    2019
# Name: Online Security, dtype: int64
#
# Distribution of Online Backup:
# No     4614
# Yes    2429
# Name: Online Backup, dtype: int64
#
# Distribution of Device Protection Plan:
# No     4621
# Yes    2422
# Name: Device Protection Plan, dtype: int64
#
# Distribution of Premium Tech Support:
# No     4999
# Yes    2044
# Name: Premium Tech Support, dtype: int64
#
# Distribution of Streaming TV:
# No     4336
# Yes    2707
# Name: Streaming TV, dtype: int64
#
# Distribution of Streaming Movies:
# No     4311
# Yes    2732
# Name: Streaming Movies, dtype: int64
#
# Distribution of Streaming Music:
# No     4555
# Yes    2488
# Name: Streaming Music, dtype: int64
#
# ...

# %%
categorical_columns= ['Multiple Lines', 'Internet Type', 'Online Security', 'Online Backup',
                               'Device Protection Plan', 'Premium Tech Support', 'Streaming TV',
                               'Streaming Movies', 'Streaming Music', 'Unlimited Data']

# Loop through each column and plot countplot
for col in categorical_columns:
    print(f'Crosstab of {col} and Customer Status:')
    print(pd.crosstab(df['Customer Status'], df[col]))
    print('\n')
# Out:
# Crosstab of Multiple Lines and Customer Status:
# Multiple Lines     No   Yes
# Customer Status
# Churned          1019   850
# Joined            409    45
# Stayed           2644  2076
#
#
# Crosstab of Internet Type and Customer Status:
# Internet Type    Cable   DSL  Fiber Optic
# Customer Status
# Churned            213   307         1349
# Joined              56   115          283
# Stayed             561  1230         2929
#
#
# Crosstab of Online Security and Customer Status:
# Online Security    No   Yes
# Customer Status
# Churned          1574   295
# Joined            408    46
# Stayed           3042  1678
#
#
# Crosstab of Online Backup and Customer Status:
# Online Backup      No   Yes
# Customer Status
# Churned          1346   523
# Joined            400    54
# Stayed           2868  1852
#
#
# Crosstab of Device Protection Plan and Customer Status:
# Device Protection Plan    No   Yes
# Customer Status
# Churned                 1324   545
# ...

# %%
#combine 'Latitude', 'Longitude'
df['Region'] = list(zip(df['Latitude'], df['Longitude']))

# %%
df.head()
# Out:
#   Customer ID  Gender  Age Married  Number of Dependents          City  \
# 0  0002-ORFBO  Female   37     Yes                   0.0  Frazier Park
# 1  0003-MKNFE    Male   46      No                   0.0      Glendale
# 2  0004-TLHLJ    Male   50      No                   0.0    Costa Mesa
# 3  0011-IGKFF    Male   78     Yes                   0.0      Martinez
# 4  0013-EXCHZ  Female   75     Yes                   0.0     Camarillo
#
#    Zip Code   Latitude   Longitude  Number of Referrals  ...   Payment Method  \
# 0     93225  34.827662 -118.999073             1.414214  ...      Credit Card
# 1     91206  34.162515 -118.203869             0.000000  ...      Credit Card
# 2     92627  33.645672 -117.922613             0.000000  ...  Bank Withdrawal
# 3     94553  38.014457 -122.115432             1.000000  ...  Bank Withdrawal
# 4     93010  34.227846 -119.079903             1.732051  ...      Credit Card
#
# ...

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Age', 'Married', 'Number of Dependents',
#        'City', 'Zip Code', 'Latitude', 'Longitude', 'Number of Referrals',
#        'Tenure in Months', 'Offer', 'Phone Service',
#        'Avg Monthly Long Distance Charges', 'Multiple Lines',
#        'Internet Service', 'Internet Type', 'Avg Monthly GB Download',
#        'Online Security', 'Online Backup', 'Device Protection Plan',
#        'Premium Tech Support', 'Streaming TV', 'Streaming Movies',
#        'Streaming Music', 'Unlimited Data', 'Contract', 'Paperless Billing',
#        'Payment Method', 'Monthly Charge', 'Total Charges', 'Total Refunds',
#        'Total Extra Data Charges', 'Total Long Distance Charges',
#        'Total Revenue', 'Customer Status', 'Customer Status Encoded', 'Region',
#        'Add-on Service Count', 'Add-On Services Count'],
#       dtype='object')

# %%
for col in ['Online Security', 'Online Backup', 'Device Protection Plan', 
            'Premium Tech Support', 'Streaming TV', 'Streaming Movies', 'Streaming Music']:
    print(f"{col} value counts:")
    print(df[col].value_counts())
    print()
# Out:
# Online Security value counts:
# No     5024
# Yes    2019
# Name: Online Security, dtype: int64
#
# Online Backup value counts:
# No     4614
# Yes    2429
# Name: Online Backup, dtype: int64
#
# Device Protection Plan value counts:
# No     4621
# Yes    2422
# Name: Device Protection Plan, dtype: int64
#
# Premium Tech Support value counts:
# No     4999
# Yes    2044
# Name: Premium Tech Support, dtype: int64
#
# Streaming TV value counts:
# No     4336
# Yes    2707
# Name: Streaming TV, dtype: int64
#
# Streaming Movies value counts:
# No     4311
# Yes    2732
# Name: Streaming Movies, dtype: int64
#
# Streaming Music value counts:
# No     4555
# Yes    2488
# Name: Streaming Music, dtype: int64

# %%
df['Add-On Services Count'] = df[['Online Security', 'Online Backup', 'Device Protection Plan', 
                                  'Premium Tech Support', 'Streaming TV', 
                                  'Streaming Movies', 'Streaming Music']].apply(lambda row: row.eq('Yes').sum(), axis=1)

# %%
print(df['Add-On Services Count'].dtype)
print(df['Customer Status Encoded'].dtype)
# Out:
# int64
# int64

# %%
print(df['Add-On Services Count'].nunique())
print(df['Customer Status Encoded'].nunique())
# Out:
# 8
# 3

# %%
print(df['Add-On Services Count'].value_counts())
print(df['Customer Status Encoded'].value_counts())
# Out:
# 0    2173
# 3     901
# 2     852
# 4     851
# 1     827
# 5     688
# 6     494
# 7     257
# Name: Add-On Services Count, dtype: int64
# 2    4720
# 0    1869
# 1     454
# Name: Customer Status Encoded, dtype: int64

# %%
print(df['Add-On Services Count'].isnull().sum())
print(df['Customer Status Encoded'].isnull().sum())
# Out:
# 0
# 0

# %%
correlation = df['Add-On Services Count'].corr(df['Customer Status Encoded'])
print(f'Correlation with Customer Status: {correlation}')
# Out:
# Correlation with Customer Status: 0.12113135118446855

# %%
import matplotlib.pyplot as plt

# Group by Customer Status and calculate the mean of Add-On Services Count
add_on_services_mean = df.groupby('Customer Status')['Add-On Services Count'].mean()

# Create a bar plot
add_on_services_mean.plot(kind='bar', color='skyblue', edgecolor='black', figsize=(8, 6))
plt.title('Mean Add-On Services Count by Customer Status')
plt.xlabel('Customer Status')
plt.ylabel('Mean Add-On Services Count')
plt.xticks(rotation=0) 
plt.show()

# %%
import seaborn as sns

# Create a box plot
plt.figure(figsize=(8, 6))
sns.boxplot(x='Customer Status', y='Add-On Services Count', data=df, palette='pastel')
plt.title('Distribution of Add-On Services Count by Customer Status')
plt.xlabel('Customer Status')
plt.ylabel('Add-On Services Count')
plt.show()
